# %%
import pandas as pd
pd.options.display.max_columns=50
from scipy import stats as st
import numpy as np
from statsmodels.sandbox.stats.multicomp import fdrcorrection0
import matplotlib.pyplot as plt

# %%
def get_label(row):
    if ((not(row["CANCER_SYMBOL"]) is np.nan) and row["CANCER_SYMBOL"]!="EGFR") or ((not(row["CANCER_SYMBOL"]) is np.nan) and ("." in row["gene"])):
        gene=row["CANCER_SYMBOL"].split("_")[0] # get only one
    else:
        gene=row["gene"].split("_")[0] # gget only one
    treatment=row["drug"]
    ttype=row["cancertype"]
    return f"{gene} - {treatment} ({ttype})"

# %%
comb = pd.read_excel("../data/filtered_peak_overview_ploidy_plus_2.5_qvalue05_final_NOV2022.xlsx")
comb["log_qvalue"] = -np.log10(comb["q.value_TT_fdr"].values)
comb["representative_mech"] = comb["Mark"] == "X"
d_maxv_mc=comb[(comb["q.value_TT_fdr"]<0.05)&(comb["log2_Fisher_Est"]>0)].groupby(["gene","cancertype"]).agg({"q.value_TT_fdr":np.nanmin}).to_dict()["q.value_TT_fdr"]
comb["representative_mech"] = comb.apply(lambda row: d_maxv_mc[(row["gene"],row["cancertype"])] == row["q.value_TT_fdr"] if ((row["gene"],row["cancertype"]) in d_maxv_mc and row["q.value_TT_fdr"] < 0.05) else False,axis=1)
comb["annotated"] = comb["Known"] == "Yes"
comb["type_alt"] = comb["SV_type"]
comb["label"] = comb.apply(lambda row: get_label(row),axis=1)
comb["cancer_type_code"] =comb["cancertype"].str.replace("-","_")
comb["not_gene"] = comb.apply(lambda row: (row["gene"].startswith("RP") or row["gene"].startswith("RN") or row["gene"].startswith("RP")) and (str(row["CANCER_SYMBOL"])=="nan"),axis=1 )

# %% [markdown]
# ### Save the data

# %%
comb[["gene","drug","cancer_type_code","drug_cancer_gene","label","type_alt","q.value_TT_fdr","log_qvalue","log2_Fisher_Est","HMF_treat_2","PCAWG_notreat_2","annotated","representative_mech","not_gene"]].rename(
    columns={"q.value_TT_fdr":"qvalue","log2_Fisher_Est":"log_odds_ratio","HMF_treat_2":"mutated_t","PCAWG_notreat_2":"mutated_c"}).to_csv("../data/cnv_results_resistance.tsv.gz",sep="\t",index=False)

# %% [markdown]
# ### Save only significant

# %%
comb[(comb["q.value_TT_fdr"]<0.05)&(comb["log2_Fisher_Est"]>0)&(comb["not_gene"]==False)].to_csv("../data/significant_hits_cnv.tsv",sep="\t",index=False)

# %%
comb[(comb["q.value_TT_fdr"]<0.05)&(comb["log2_Fisher_Est"]>0)&(comb["not_gene"]==False)]
# Out:
#                      drug cancertype          gene         newpeakID  \
# 0               Anti_HER2       BRCA         ERBB2  Amp_peak_chr17_1
# 1          mTOR_inhibitor       BRCA        ZNF583  Amp_peak_chr19_5
# 2          mTOR_inhibitor       BRCA         MYEOV  Amp_peak_chr11_3
# 3           Anti_AR__GnRH       BRCA          CLTC  Amp_peak_chr17_3
# 4   Pyrimidine_antagonist       BRCA          TYMS  Amp_peak_chr18_1
# 5   Pyrimidine_antagonist       BRCA        ZNF784  Amp_peak_chr19_4
# 6                  Taxane       BRCA    AC005808.3  Amp_peak_chr20_1
# 8           Anti_AR__GnRH       PRAD        PRNCR1   Amp_peak_chr8_1
# 9              Alkylating       BRCA         TSHZ2  Amp_peak_chr20_3
# 10  Multikinase_inhibitor       KIRC  RP11-145E5.5   Del_peak_chr9_1
# 12              Anti_EGFR       LUAD          EGFR   Amp_peak_chr7_1
# 13  Pyrimidine_antagonist       PAAD         CDK12  Amp_peak_chr17_2
# 14          Anti_AR__GnRH       PRAD            AR   Amp_peak_chrX_1
# 15                 Taxane       PRAD          TP53  Del_peak_chr17_1
# 16          Anti_AR__GnRH       PRAD         SAMD8  Amp_peak_chr10_1
# 17          Anti_AR__GnRH       PRAD          KLLN  Del_peak_chr10_1
# 18                 Taxane       PRAD    AC074323.1  Amp_peak_chr10_2
# 19                 Taxane       PRAD        ADAM15   Amp_peak_chr1_2
# 20                 Taxane       PRAD       IGHMBP2  Amp_peak_chr11_1
#
#    CANCER_SYMBOL SV_type  length  HMF_treat_2  HMF_treat_0  PCAWG_notreat_2  \
# 0     ERBB2_CLTC     Amp  101246           52           26               29
# 1            NaN     Amp   72881           10           57                1
# 2            NaN     Amp   24086           24           43               28
# 3     ERBB2_CLTC     Amp   36384           21           57               19
# 4            NaN     Amp  680141           25          263                3
# 5            NaN     Amp  121038           17          271                1
# 6            NaN     Amp  277441           74          293               20
# 8            NaN     Amp   42711          116          208                1
# 9            NaN     Amp  411546           63          322               15
# 10        CDKN2A     Del  587789            5           17                3
# 12          EGFR     Amp  559411           26           15                7
# 13           NaN     Amp  413050            4           18                6
# 14            AR     Amp   46816          127          197                1
# 15          TP53     Del   34301           33          196                1
# 16         KAT6B     Amp  213632           36          288                1
# 17          PTEN     Del  414950           85          239               14
# 18         KAT6B     Amp  162287           26          203                1
# 19           NaN     Amp  136737           19          210                1
# 20           NaN     Amp   50469           18          211                1
#
#     PCAWG_notreat_0  rank       q.values  q.value_TT_fdr  Fisher_Est  \
# 0               172     1   5.910000e-77    1.519737e-14   11.715947
# 1               200     1   3.840000e-03    3.757087e-04   34.565882
# 2               173     1   4.310000e-22    1.594226e-02    3.429443
# 3               182     1   1.790000e-11    2.592857e-02    3.509958
# 4               198     1   7.800000e-03    2.677465e-02    6.256276
# 5               200     1   3.190000e-02    3.283497e-02   12.507630
# 6               181     1   6.970000e-22    3.877677e-02    2.282586
# 8               152     1   6.880000e-23    9.896911e-20   84.336698
# 9               186     1   6.430000e-19    4.569219e-02    2.422816
# 10              106     1   4.140000e-07    3.422311e-02   10.090384
# 12               29     1   1.310000e-11    1.289641e-02    6.976396
# 13              212     1   2.040000e-04    3.989130e-02    7.719727
# 14              152     1  1.560000e-202    8.128138e-22   97.461399
# 15              152     1   6.800000e-56    5.544613e-05   25.472897
# 16              153     1   3.480000e-08    3.681315e-04   19.064793
# 17              139     1  2.370000e-126    3.681315e-04    3.522820
# 18              153     1   1.890000e-05    5.410654e-04   19.510209
# 19              153     1   7.750000e-04    1.171289e-02   13.786844
# 20              152     1   8.820000e-04    1.896087e-02   12.915139
#
#     log2_Fisher_Est  n_fraction  nn_fraction  delft_fraction  HMFsamples  \
# 0          3.550402    0.666667     0.144279        0.522388          78
# 1          5.111277    0.149254     0.004975        0.144279          67
# 2          1.777974    0.358209     0.139303        0.218905          67
# 3          1.811454    0.269231     0.094527        0.174703          78
# 4          2.645304    0.086806     0.014925        0.071880         288
# 5          3.644737    0.059028     0.004975        0.054053         288
# 6          1.190669    0.201635     0.099502        0.102132         367
# 8          6.398089    0.358025     0.006536        0.351489         324
# 9          1.276685    0.163636     0.074627        0.089009         385
# 10         3.334909    0.227273     0.027523        0.199750          22
# 12         2.802482    0.634146     0.194444        0.439702          41
# 13         2.948550    0.181818     0.027523        0.154295          22
# 14         6.606759    0.391975     0.006536        0.385439         324
# 15         4.670891    0.144105     0.006536        0.137569         229
# 16         4.252839    0.111111     0.006494        0.104618         324
# 17         1.816731    0.262346     0.091503        0.170842         324
# 18         4.286157    0.113537     0.006494        0.107044         229
# 19         3.785220    0.082969     0.006494        0.076476         229
# 20         3.690991    0.078603     0.006536        0.072067         229
#
#                                      drug_cancer_gene Mark Known  log_qvalue  \
# 0                 Anti_HER2::ERBB2 (BRCA::ERBB2_CLTC)    X   Yes   13.818231
# 1                     mTOR_inhibitor::ZNF583 (BRCA::)  NaN   NaN    3.425149
# 2                      mTOR_inhibitor::MYEOV (BRCA::)  NaN   NaN    1.797450
# 3              Anti_AR__GnRH::CLTC (BRCA::ERBB2_CLTC)  NaN   NaN    1.586221
# 4                Pyrimidine_antagonist::TYMS (BRCA::)    X   NaN    1.572276
# 5              Pyrimidine_antagonist::ZNF784 (BRCA::)  NaN   NaN    1.483663
# 6                         Taxane::AC005808.3 (BRCA::)  NaN   NaN    1.411428
# 8                      Anti_AR__GnRH::PRNCR1 (PRAD::)    X   Yes   19.004500
# 9                          Alkylating::TSHZ2 (BRCA::)  NaN   NaN    1.340158
# 10  Multikinase_inhibitor::RP11-145E5.5 (KIRC::CDK...  NaN   NaN    1.465681
# 12                       Anti_EGFR::EGFR (LUAD::EGFR)    X   Yes    1.889531
# 13              Pyrimidine_antagonist::CDK12 (PAAD::)  NaN   NaN    1.399122
# 14                       Anti_AR__GnRH::AR (PRAD::AR)    X   Yes   21.090009
# 15                          Taxane::TP53 (PRAD::TP53)  NaN   NaN    4.256129
# 16                 Anti_AR__GnRH::SAMD8 (PRAD::KAT6B)    X   Yes    3.433997
# 17                   Anti_AR__GnRH::KLLN (PRAD::PTEN)    X   Yes    3.433997
# 18                   Taxane::AC074323.1 (PRAD::KAT6B)  NaN   NaN    3.266750
# 19                            Taxane::ADAM15 (PRAD::)  NaN   NaN    1.931336
# 20                           Taxane::IGHMBP2 (PRAD::)  NaN   NaN    1.722142
#
#     representative_mech  annotated type_alt  \
# 0                  True       True      Amp
# 1                  True      False      Amp
# 2                  True      False      Amp
# 3                  True      False      Amp
# 4                  True      False      Amp
# 5                  True      False      Amp
# 6                  True      False      Amp
# 8                  True       True      Amp
# 9                  True      False      Amp
# 10                 True      False      Del
# 12                 True       True      Amp
# 13                 True      False      Amp
# 14                 True       True      Amp
# 15                 True      False      Del
# 16                 True       True      Amp
# 17                 True       True      Del
# 18                 True      False      Amp
# 19                 True      False      Amp
# 20                 True      False      Amp
#
#                                     label cancer_type_code  not_gene
# 0                ERBB2 - Anti_HER2 (BRCA)             BRCA     False
# 1          ZNF583 - mTOR_inhibitor (BRCA)             BRCA     False
# 2           MYEOV - mTOR_inhibitor (BRCA)             BRCA     False
# 3            ERBB2 - Anti_AR__GnRH (BRCA)             BRCA     False
# 4     TYMS - Pyrimidine_antagonist (BRCA)             BRCA     False
# 5   ZNF784 - Pyrimidine_antagonist (BRCA)             BRCA     False
# 6              AC005808.3 - Taxane (BRCA)             BRCA     False
# 8           PRNCR1 - Anti_AR__GnRH (PRAD)             PRAD     False
# 9               TSHZ2 - Alkylating (BRCA)             BRCA     False
# 10  CDKN2A - Multikinase_inhibitor (KIRC)             KIRC     False
# 12                EGFR - Anti_EGFR (LUAD)             LUAD     False
# 13   CDK12 - Pyrimidine_antagonist (PAAD)             PAAD     False
# 14              AR - Anti_AR__GnRH (PRAD)             PRAD     False
# 15                   TP53 - Taxane (PRAD)             PRAD     False
# 16           KAT6B - Anti_AR__GnRH (PRAD)             PRAD     False
# 17            PTEN - Anti_AR__GnRH (PRAD)             PRAD     False
# 18                  KAT6B - Taxane (PRAD)             PRAD     False
# 19                 ADAM15 - Taxane (PRAD)             PRAD     False
# 20                IGHMBP2 - Taxane (PRAD)             PRAD     False
